# %% [markdown]
# # QDIST v4.0.0 final scientific adjudication and freeze preparation
#
# This notebook finalizes the accepted cohort candidate without recomputing feature extraction.

# %%
from pathlib import Path
import json, os, sys

RUN_PACKAGE_TESTS = True
RUN_FINALIZATION = True
PROJECT_ROOT_OVERRIDE = 'C:\\Users\\musikicn\\Desktop\\Nevena_project\\Paper_1\\paper_1'
SCIENTIFIC_REVIEW_DECISION = "ACCEPT_QDIST_V400"
SCIENTIFIC_REVIEWER = "Nevena Musikic"
PUBLISH_AND_FREEZE = False

if PUBLISH_AND_FREEZE:
    raise RuntimeError("Publication/freezing is performed only by the separate atomic freeze scripts.")

PROJECT_ROOT = Path(PROJECT_ROOT_OVERRIDE).resolve() if PROJECT_ROOT_OVERRIDE else Path.cwd().resolve()
while not (PROJECT_ROOT / "src reviewed").exists() and PROJECT_ROOT.parent != PROJECT_ROOT:
    PROJECT_ROOT = PROJECT_ROOT.parent
print("Project root:", PROJECT_ROOT)
print("Decision:", SCIENTIFIC_REVIEW_DECISION)
# Out:
# Project root: C:\Users\musikicn\Desktop\Nevena_project\Paper_1\paper_1
# Decision: ACCEPT_QDIST_V400

# %%
if RUN_PACKAGE_TESTS:
    import subprocess
    tests = [
        PROJECT_ROOT / "tests reviewed" / "test_qdist_v400.py",
        PROJECT_ROOT / "tests reviewed" / "test_qdist_v400_notebook.py",
        PROJECT_ROOT / "tests reviewed" / "test_qdist_v400_cohort.py",
        PROJECT_ROOT / "tests reviewed" / "test_qdist_v400_final.py",
    ]
    result = subprocess.run([str(PROJECT_ROOT / ".venv" / "Scripts" / "python.exe"), "-m", "pytest", *map(str, tests), "-q", "--disable-warnings"], cwd=PROJECT_ROOT)
    if result.returncode:
        raise RuntimeError("Reviewed QDIST tests failed")

# %%
sys.path.insert(0, str(PROJECT_ROOT / "src reviewed"))
from paper1_qc_reviewed.qdist_v400_final import finalize_candidate

SOURCE_ROOT = PROJECT_ROOT / "outputs reviewed" / "nonlinear_distortion" / "qdist-v4.0.0-candidate"
FINAL_ROOT = PROJECT_ROOT / "outputs reviewed" / "nonlinear_distortion" / "qdist-v4.0.0"
PROVENANCE = PROJECT_ROOT / "notebooks reviewed" / "05_QDIST"

required_provenance = [
    PROVENANCE / "QDIST_v400_FINAL_SCIENTIFIC_AUDIT.md",
    PROVENANCE / "QDIST_v400_FINAL_FEATURE_DECISIONS.csv",
    PROVENANCE / "QDIST_Family_Evaluation_Workbook_v1_0.docx",
    PROVENANCE / "QDIST_V4_0_0_FREEZE_CONTRACT.md",
    PROVENANCE / "QDIST_Validation_Checklist_v1_0.csv",
    PROVENANCE / "QDIST_Ten_Domain_Dashboard_v1_0.csv",
    PROVENANCE / "QDIST_Gate_Summary_FINAL_v1_0.csv",
    PROVENANCE / "QDIST_V400_FINALIZATION_IMPLEMENTATION_REPORT.md",
]
for path in required_provenance:
    if not path.exists():
        raise FileNotFoundError(path)
print("Source candidate:", SOURCE_ROOT)
print("Final candidate:", FINAL_ROOT)
# Out:
# Source candidate: C:\Users\musikicn\Desktop\Nevena_project\Paper_1\paper_1\outputs reviewed\nonlinear_distortion\qdist-v4.0.0-candidate
# Final candidate: C:\Users\musikicn\Desktop\Nevena_project\Paper_1\paper_1\outputs reviewed\nonlinear_distortion\qdist-v4.0.0

# %%
if RUN_FINALIZATION:
    manifest = finalize_candidate(
        source_root=SOURCE_ROOT,
        final_root=FINAL_ROOT,
        scientific_review_decision=SCIENTIFIC_REVIEW_DECISION,
        scientific_reviewer=SCIENTIFIC_REVIEWER,
        scientific_review_rationale=(
            "Post-cohort G1-G10 scientific audit accepted with explicit sparse-positive, "
            "reliability, and AI-assisted event-review qualifications."
        ),
        provenance_files=required_provenance,
    )
    print(json.dumps(manifest, indent=2))
# Out:
# {
#   "measurement_version": "qdist-v4.0.0",
#   "source_measurement_version": "qdist-v4.0.0-candidate",
#   "legacy_measurement_version": "qdist-v3.1.1",
#   "finalization_revision": "qdist-v4.0.0-finalization-r1",
#   "figure_package_version": "qdist-v4.0.0-figures-v1.0.0",
#   "freeze_status": "ready_for_atomic_freeze",
#   "freeze_allowed": true,
#   "scientific_review_decision": "ACCEPT_QDIST_V400",
#   "scientific_reviewer": "Nevena Musikic",
#   "scientific_review_rationale": "Post-cohort G1-G10 scientific audit accepted with explicit sparse-positive, reliability, and AI-assisted event-review qualifications.",
#   "recording_count": 519,
#   "participant_count": 224,
#   "available_recording_count": 519,
#   "positive_recording_count": 6,
#   "valid_zero_recording_count": 513,
#   "candidate_plateau_count": 861,
#   "accepted_plateau_count": 30,
#   "episode_count": 15,
#   "event_review_item_count": 60,
#   "event_review_standardized_png_count": 60,
#   "event_review_adjudication_type": "AI-assisted blinded morphology review",
#   "event_review_independent_human_ground_truth": false,
#   "event_review_rejected_ambiguous_count": 13,
#   "positive_part_repeatability_estimable": false,
#   "numerical_equivalence_to_cohort_candidate": true,
#   "numerical_equivalence_to_qdist_v311": true,
#   "feature_values_recomputed": false,
#   "source_recording_feature_sha256": "385186a5e119fd93fc5344396fa75ff3174e42d744146f6bfaeeefafc0d58144",
#   "analysis_features": [
#     "qdist_hard_clipped_frame_fraction",
#     "qdist_hard_clip_event_rate_per_min",
#     "qdist_hard_clipped_sample_fraction"
#   ],
#   "feature_decisions": [
#     {
#       "feature": "qdist_hard_clipped_frame_fraction",
#       "final_decision": "RETAIN_PRIMARY_RELATED_VIEW",
#       "publication_role": "primary recording-level prevalence view: fraction of complete native-waveform frames intersecting at least one accepted hard-clipping plateau",
#       "default_manuscript_inclusion": true,
#       "default_joint_model_inclusion": true
#     },
#     {
#       "feature": "qdist_hard_clip_event_rate_per_min",
#       "final_decision": "RETAIN_PRIMARY_EVENT_WITH_UNCERTAINTY",
#       "publication_role": "primary event view: merged accepted hard-clipping episodes per finite native task-span minute, accompanied by event count and exact Poisson interval",
#       "default_manuscript_inclusion": true,
#       "default_joint_model_inclusion": true
#     },
#     {
#       "feature": "qdist_hard_clipped_sample_fraction",
#       "final_decision": "RETAIN_SECONDARY_RELATED_VIEW",
#       "publication_role": "secondary direct channel-sample burden view; report with clipped channel-ms/min",
#       "default_manuscript_inclusion": true,
#       "default_joint_model_inclusion": false
#     }
#   ],
#   "figure_count": 23,
#   "main_figure_bundle_count": 15,
#   "gallery_bundle_count": 8,
#   "required_panels_complete": true,
#   "panel_i_status": "APPLICABLE_complete_event_verification",
#   "regenerated_figure_stems": [
#     "D2_occurrence_sparsity",
#     "E1_detector_parameter_sensitivity",
#     "E2_episode_grouping_sensitivity",
#     "E3_sparse_burden_deletion_poisson",
#     "F_empirical_distributions",
#     "H1_repeated_recording_persistence",
#     "H2_related_view_redundancy",
#     "H3_participant_weighting_clustering",
#     "I_event_verification",
#     "J_ml_handoff"
#   ],
#   "family_scalar_status": "prohibited_not_constructed",
#   "family_scalar_constructed": false,
#   "standalone_gate_allowed": false,
#   "complete_nonlinear_distortion_claim_allowed": false,
#   "missing_values_imputed": false,
#   "created_utc": "2026-08-04T18:11:04.234992+00:00",
#   "immutability_policy": "freeze scripts refuse overwrite; any numerical change requires a new semantic measurement version"
# }

# %%
required = {
    "measurement_version": "qdist-v4.0.0",
    "freeze_status": "ready_for_atomic_freeze",
    "freeze_allowed": True,
    "recording_count": 519,
    "participant_count": 224,
    "available_recording_count": 519,
    "positive_recording_count": 6,
    "valid_zero_recording_count": 513,
    "event_review_item_count": 60,
    "event_review_standardized_png_count": 60,
    "figure_count": 23,
    "main_figure_bundle_count": 15,
    "gallery_bundle_count": 8,
    "required_panels_complete": True,
    "panel_i_status": "APPLICABLE_complete_event_verification",
    "numerical_equivalence_to_cohort_candidate": True,
    "numerical_equivalence_to_qdist_v311": True,
    "feature_values_recomputed": False,
    "family_scalar_constructed": False,
    "standalone_gate_allowed": False,
    "complete_nonlinear_distortion_claim_allowed": False,
    "missing_values_imputed": False,
}
for key, expected in required.items():
    if manifest.get(key) != expected:
        raise AssertionError(f"Manifest mismatch {key}: {manifest.get(key)!r}")
print("Final manifest contract verified.")
# Out:
# Final manifest contract verified.

# %%
print("QDIST v4.0.0 FINALIZATION COMPLETE")
print("Candidate is ready for atomic freeze.")
print("PUBLISH_AND_FREEZE remains", PUBLISH_AND_FREEZE)
# Out:
# QDIST v4.0.0 FINALIZATION COMPLETE
# Candidate is ready for atomic freeze.
# PUBLISH_AND_FREEZE remains False
